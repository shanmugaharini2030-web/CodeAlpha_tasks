# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


data = {
    "Age": [22, 25, 28, 30, 35, 40, 45, 50, 29, 33],
    "Salary": [20000, 25000, 30000, 35000, 40000, 50000, 60000, 70000, 32000, 38000],
    "Department": ["IT", "HR", "IT", "Finance", "HR", "IT", "Finance", "HR", "IT", "Finance"]
}

df = pd.DataFrame(data)

print("First 5 rows of dataset:")
print(df.head())


print("\nEDA Questions:")
print("1. What is the average salary?")
print("2. Are there missing values?")
print("3. How is salary distributed?")
print("4. Is there a relationship between age and salary?")
print("5. Are there any outliers?")


print("\nDataset Info:")
df.info()

print("\nShape:", df.shape)
print("Columns:", df.columns)


print("\nStatistical Summary:")
print(df.describe())


print("\nMissing Values:")
print(df.isnull().sum())


plt.hist(df['Salary'], bins=5)
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.title("Salary Distribution")
plt.show()


plt.scatter(df['Age'], df['Salary'])
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Age vs Salary")
plt.show()


df['Department'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Department Distribution")
plt.ylabel("")
plt.show()


print("\nAverage Salary:", mean_salary)

Rows:", df.duplicated().sum())

sns.boxplot(x=df['Salary'])
plt.title("Salary Outliers")
plt.show()

print("\nEDA Completed Successfully ✅")
# Out:
# First 5 rows of dataset:
#    Age  Salary Department
# 0   22   20000         IT
# 1   25   25000         HR
# 2   28   30000         IT
# 3   30   35000    Finance
# 4   35   40000         HR
#
# EDA Questions:
# 1. What is the average salary?
# 2. Are there missing values?
# 3. How is salary distributed?
# 4. Is there a relationship between age and salary?
# 5. Are there any outliers?
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age         10 non-null     int64
#  1   Salary      10 non-null     int64
#  2   Department  10 non-null     object
# dtypes: int64(2), object(1)
# memory usage: 372.0+ bytes
#
# Shape: (10, 3)
# Columns: Index(['Age', 'Salary', 'Department'], dtype='object')
#
# Statistical Summary:
#              Age        Salary
# count  10.000000     10.000000
# mean   33.700000  40000.000000
# ...
